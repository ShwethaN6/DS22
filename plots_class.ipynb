# %% [markdown]
# <a href="https://colab.research.google.com/github/ShwethaN6/DS22/blob/main/plots_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#Figure size setting
#plt.figure(figsize = (20,10))

# %%
fifa_file = pd.read_csv("https://github.com/ShwethaN6/Datascience-Batch-22/blob/main/11.%20Data%20Visualization%20-%2026-11-2023/data-for-datavis/insurance.csv", delimiter='\t')

# %%
plt.figure(figsize = (20,10))

# %%
insurance_data = pd.read_csv("https://raw.githubusercontent.com/ShwethaN6/Datascience-Batch-22/main/11.%20Data%20Visualization%20-%2026-11-2023/data-for-datavis/insurance.csv", delimiter=',')

# %%
insurance_data.head
# Out:
# <bound method NDFrame.head of       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]>

# %%
sns.scatterplot(x=insurance_data['age'],y=insurance_data['charges'])
# Out:
# <Axes: xlabel='age', ylabel='charges'>

# %%
sns.scatterplot(x = insurance_data['age'], y = insurance_data['charges'],hue = insurance_data['smoker'])
# Out:
# <Axes: xlabel='age', ylabel='charges'>

# %%
sns.scatterplot(x = insurance_data['bmi'], y = insurance_data['charges'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
sns.scatterplot(x = insurance_data['bmi'], y = insurance_data['charges'],hue = insurance_data['smoker'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
sns.swarmplot(x = insurance_data['smoker'], y = insurance_data['charges'])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 37.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='smoker', ylabel='charges'>
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 60.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(insurance_data)

# %%
#Figure size setting
plt.figure(figsize = (20,10))

plt.title("Heatmap of all the columns for insurance charges")


insurance_corr = insurance_data.corr()
sns.heatmap(data=insurance_corr,annot = True,vmin = -1,vmax = 1,center=0)

plt.xlabel("columns Names")
# Out:
# <ipython-input-15-ec4048c97662>:7: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   insurance_corr = insurance_data.corr()
# Text(0.5, 80.7222222222222, 'columns Names')

# %%
sns.regplot(x='bmi',y='charges',data=insurance_data)
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
sns.kdeplot(data=insurance_data['bmi'], fill=True)
plt.show()
